# %%
import pandas as pd
import re
df = pd.read_excel('마켓컬리 하몽 전처리된 데이터.xlsx')
df
# Out:
#       Unnamed: 0  number           product detail_product        title  \
# 0              0       0  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스       처음 구입
# 1              1       1  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스         세라노
# 2              2       2  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스        맛있어요
# 3              3       3  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스         좋아요
# 4              4       4  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스      그망ㄱ,래용
# ...          ...     ...               ...            ...          ...
# 4608        4608    4608  [니코하몽] 스페인 하몽 5종  이베리코 살치촌 슬라이스        와인에굿
# 4609        4609    4609  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스  가끔 하몽 생각나면
# 4610        4610    4610  [니코하몽] 스페인 하몽 5종  이베리코 살치촌 슬라이스        와인안주
# 4611        4611    4611  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스         짱맛~
# 4612        4612    4612  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스        맛있어요
#
#                           content_review grade        date  review-like-cnt  \
# 0                         약간 마른 듯한 느낌이에요  프렌즈   2021-02-08                0
# 1              그냥 그래요  특이한 향도 나지 않고 밍밍해요  화이트   2021-02-07                0
# 2         맛만 보려했는데 하나 뜯어서 그자리에서 다 먹어버렸네요   NaN  2021-02-07                0
# 3                            약간 매콤하고 좋아요  화이트   2021-02-07                0
# 4                        기대한것만큼은 아닌ㄴ거같네영   NaN  2021-02-07                0
# ...                                  ...   ...         ...              ...
# 4608                          와인과찰떡궁합!!!   NaN  2018-10-21                0
# 4609   먹어요 너무 짜면 흰밥에 돌돌 말아서 먹어요  밥 반찬으로요  프렌즈   2018-10-20                0
# 4610                          술안주로 굿이네여~  프렌즈   2018-10-20                0
# 4611                          와인안주로 좋아요~   NaN  2018-10-19                0
# 4612                      와인안주에 꼭 필요해요 ㅋ   NaN  2018-10-19                0
#
#       review-hit-cnt
# 0                  0
# 1                  2
# 2                  6
# 3                  3
# 4                  1
# ...              ...
# 4608              29
# 4609              38
# 4610              18
# 4611              67
# 4612              47
#
# [4613 rows x 10 columns]

# %%
df["total content"] = df["title"] + " " + df["content_review"]
df
# Out:
#       Unnamed: 0  number           product detail_product        title  \
# 0              0       0  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스       처음 구입
# 1              1       1  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스         세라노
# 2              2       2  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스        맛있어요
# 3              3       3  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스         좋아요
# 4              4       4  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스      그망ㄱ,래용
# ...          ...     ...               ...            ...          ...
# 4608        4608    4608  [니코하몽] 스페인 하몽 5종  이베리코 살치촌 슬라이스        와인에굿
# 4609        4609    4609  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스  가끔 하몽 생각나면
# 4610        4610    4610  [니코하몽] 스페인 하몽 5종  이베리코 살치촌 슬라이스        와인안주
# 4611        4611    4611  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스         짱맛~
# 4612        4612    4612  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스        맛있어요
#
#                           content_review grade        date  review-like-cnt  \
# 0                         약간 마른 듯한 느낌이에요  프렌즈   2021-02-08                0
# 1              그냥 그래요  특이한 향도 나지 않고 밍밍해요  화이트   2021-02-07                0
# 2         맛만 보려했는데 하나 뜯어서 그자리에서 다 먹어버렸네요   NaN  2021-02-07                0
# 3                            약간 매콤하고 좋아요  화이트   2021-02-07                0
# 4                        기대한것만큼은 아닌ㄴ거같네영   NaN  2021-02-07                0
# ...                                  ...   ...         ...              ...
# 4608                          와인과찰떡궁합!!!   NaN  2018-10-21                0
# 4609   먹어요 너무 짜면 흰밥에 돌돌 말아서 먹어요  밥 반찬으로요  프렌즈   2018-10-20                0
# 4610                          술안주로 굿이네여~  프렌즈   2018-10-20                0
# 4611                          와인안주로 좋아요~   NaN  2018-10-19                0
# 4612                      와인안주에 꼭 필요해요 ㅋ   NaN  2018-10-19                0
#
#       review-hit-cnt                                   total content
# 0                  0                          처음 구입   약간 마른 듯한 느낌이에요
# 1                  2                 세라노   그냥 그래요  특이한 향도 나지 않고 밍밍해요
# 2                  6           맛있어요   맛만 보려했는데 하나 뜯어서 그자리에서 다 먹어버렸네요
# 3                  3                               좋아요   약간 매콤하고 좋아요
# 4                  1                        그망ㄱ,래용   기대한것만큼은 아닌ㄴ거같네영
# ...              ...                                             ...
# 4608              29                               와인에굿   와인과찰떡궁합!!!
# 4609              38  가끔 하몽 생각나면   먹어요 너무 짜면 흰밥에 돌돌 말아서 먹어요  밥 반찬으로요
# 4610              18                               와인안주   술안주로 굿이네여~
# 4611              67                                짱맛~   와인안주로 좋아요~
# 4612              47                           맛있어요   와인안주에 꼭 필요해요 ㅋ
#
# [4613 rows x 11 columns]

# %%
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]+')
    result = hangul.sub('',text)
    return result

# %%
df['total content'] = df['total content'].apply(lambda x:text_cleaning(x))
df
# Out:
#       Unnamed: 0  number           product detail_product        title  \
# 0              0       0  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스       처음 구입
# 1              1       1  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스         세라노
# 2              2       2  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스        맛있어요
# 3              3       3  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스         좋아요
# 4              4       4  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스      그망ㄱ,래용
# ...          ...     ...               ...            ...          ...
# 4608        4608    4608  [니코하몽] 스페인 하몽 5종  이베리코 살치촌 슬라이스        와인에굿
# 4609        4609    4609  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스  가끔 하몽 생각나면
# 4610        4610    4610  [니코하몽] 스페인 하몽 5종  이베리코 살치촌 슬라이스        와인안주
# 4611        4611    4611  [니코하몽] 스페인 하몽 5종     하몽세라노 슬라이스         짱맛~
# 4612        4612    4612  [니코하몽] 스페인 하몽 5종  이베리코 초리조 슬라이스        맛있어요
#
#                           content_review grade        date  review-like-cnt  \
# 0                         약간 마른 듯한 느낌이에요  프렌즈   2021-02-08                0
# 1              그냥 그래요  특이한 향도 나지 않고 밍밍해요  화이트   2021-02-07                0
# 2         맛만 보려했는데 하나 뜯어서 그자리에서 다 먹어버렸네요   NaN  2021-02-07                0
# 3                            약간 매콤하고 좋아요  화이트   2021-02-07                0
# 4                        기대한것만큼은 아닌ㄴ거같네영   NaN  2021-02-07                0
# ...                                  ...   ...         ...              ...
# 4608                          와인과찰떡궁합!!!   NaN  2018-10-21                0
# 4609   먹어요 너무 짜면 흰밥에 돌돌 말아서 먹어요  밥 반찬으로요  프렌즈   2018-10-20                0
# 4610                          술안주로 굿이네여~  프렌즈   2018-10-20                0
# 4611                          와인안주로 좋아요~   NaN  2018-10-19                0
# 4612                      와인안주에 꼭 필요해요 ㅋ   NaN  2018-10-19                0
#
#       review-hit-cnt                                   total content
# 0                  0                          처음 구입   약간 마른 듯한 느낌이에요
# 1                  2                 세라노   그냥 그래요  특이한 향도 나지 않고 밍밍해요
# 2                  6           맛있어요   맛만 보려했는데 하나 뜯어서 그자리에서 다 먹어버렸네요
# 3                  3                               좋아요   약간 매콤하고 좋아요
# 4                  1                         그망ㄱ래용   기대한것만큼은 아닌ㄴ거같네영
# ...              ...                                             ...
# 4608              29                                  와인에굿   와인과찰떡궁합
# 4609              38  가끔 하몽 생각나면   먹어요 너무 짜면 흰밥에 돌돌 말아서 먹어요  밥 반찬으로요
# 4610              18                                와인안주   술안주로 굿이네여
# 4611              67                                  짱맛   와인안주로 좋아요
# 4612              47                           맛있어요   와인안주에 꼭 필요해요 ㅋ
#
# [4613 rows x 11 columns]

# %%
totalcontent_corpus = "".join(df['total content'].to_list())

# %%
from konlpy.tag import Okt
from collections import Counter

nouns_tagger = Okt()
nouns = nouns_tagger.nouns(totalcontent_corpus)
count = Counter(nouns)
count
# Out:
# Counter({'처음': 223,
#          '구입': 130,
#          '약간': 73,
#          '듯': 26,
#          '느낌': 62,
#          '세라': 166,
#          '노': 149,
#          '그냥': 211,
#          '향': 121,
#          '밍밍': 5,
#          '맛': 1133,
#          '하나': 64,
#          '자리': 8,
#          '매콤': 84,
#          '망': 1,
#          '용': 147,
#          '거': 126,
#          '굿굿': 33,
#          '하몽': 1694,
#          '와인': 1110,
#          '안주': 925,
#          '짝': 1,
#          '냄새': 212,
#          '심해': 4,
#          '원래': 34,
#          '정도': 63,
#          '것': 253,
#          '꾸리': 2,
#          '좀': 210,
#          '편': 16,
#          '양송이': 3,
#          '타파스': 12,
#          '때': 229,
#          '필름': 8,
#          '고생': 2,
#          '샌드위치': 353,
#          '초': 244,
#          '리조': 248,
#          '남편': 64,
#          '최애': 13,
#          '보고': 85,
#          '진미': 1,
#          '중': 36,
#          '구매': 535,
#          '치아바타': 27,
#          '사고': 2,
#          '멜론': 320,
#          '생햄': 12,
#          '기대': 127,
#          '살라미': 39,
#          '플레이': 22,
#          '팅': 18,
#          '마켓': 155,
#          '컬리': 393,
#          '종류': 34,
#          '별로': 100,
#          '사서': 30,
#          '술안주': 102,
#          '다른': 93,
#          '필요': 4,
#          '치즈': 438,
#          '강': 12,
#          '또': 134,
#          '강추또': 1,
#          '강추': 13,
#          '완전': 38,
#          '추천': 65,
#          '정말': 107,
#          '요': 228,
#          '재주': 5,
#          '의사': 47,
#          '메론': 401,
#          '꿀맛': 29,
#          '양도': 95,
#          '생각': 201,
#          '한장': 83,
#          '수': 165,
#          '포장': 71,
#          '샐러드': 277,
#          '해': 167,
#          '제': 86,
#          '돼지': 32,
#          '레커': 9,
#          '위': 103,
#          '입': 49,
#          '제품': 99,
#          '못': 47,
#          '해먹': 47,
#          '고민': 15,
#          '습': 22,
#          '슬': 206,
#          '라이스': 212,
#          '적': 4,
#          '겨자': 2,
#          '빵': 127,
#          '크림': 54,
#          '동안': 3,
#          '전자레인지': 1,
#          '두': 7,
#          '장': 21,
#          '올리브유': 25,
#          '통후추': 1,
#          '솔솔': 2,
#          '아침': 32,
#          '겸': 1,
#          '점심': 4,
#          '자주': 91,
#          '무난': 117,
#          '번': 79,
#          '재': 39,
#          '텐': 1,
#          '겹': 13,
#          '평': 5,
#          '리해': 2,
#          '요별': 5,
#          '비': 98,
#          '스페인': 131,
#          '비려': 17,
#          '술': 33,
#          '최고': 154,
#          '첫': 31,
#          '주문': 229,
#          '이상': 14,
#          '전혀': 11,
#          '하옹': 1,
#          '덕분': 18,
#          '비쥬': 2,
#          '얼': 6,
#          '더': 201,
#          '고급': 30,
#          '다음': 70,
#          '날': 19,
#          '도착': 6,
#          '검색': 2,
#          '여기': 19,
#          '가격': 240,
#          '배송': 104,
#          '모두': 18,
#          '베리': 128,
#          '코': 119,
#          '맛이엇어': 1,
#          '쫌더': 1,
#          '베이컨': 23,
#          '생햄이엇어': 1,
#          '존맛': 42,
#          '누락': 12,
#          '바로': 22,
#          '대응': 1,
#          '피자': 41,
#          '데': 14,
#          '초리': 9,
#          '초가': 3,
#          '짭쪼름하': 14,
#          '여러': 13,
#          '채소': 9,
#          '간이': 18,
#          '브런치': 16,
#          '사이': 9,
#          '내기': 7,
#          '역시': 56,
#          '양': 108,
#          '맥주': 126,
#          '굿': 203,
#          '기름기': 15,
#          '부분': 79,
#          '부담': 39,
#          '먹기': 297,
#          '기전': 3,
#          '미리': 6,
#          '필수': 8,
#          '꼭': 26,
#          '진짜': 123,
#          '진해': 3,
#          '후기': 125,
#          '일': 22,
#          '특유': 41,
#          '음': 38,
#          '가장자리': 1,
#          '은': 6,
#          '부라타': 50,
#          '토마토': 57,
#          '안': 70,
#          '살짝': 87,
#          '문자': 5,
#          '입문': 34,
#          '니코': 51,
#          '앞': 13,
#          '저': 105,
#          '크래커': 82,
#          '드하': 1,
#          '단': 56,
#          '조화': 16,
#          '세지': 1,
#          '거부': 14,
#          '감': 15,
#          '아유': 1,
#          '먹음': 49,
#          '오': 16,
#          '남두': 1,
#          '두번째': 21,
#          '짭쪼롬': 12,
#          '보통': 28,
#          '조각': 13,
#          '새콤짭쪼름해': 1,
#          '줄': 14,
#          '금방': 8,
#          '아들': 12,
#          '간식': 27,
#          '급': 4,
#          '주말': 13,
#          '레서피': 1,
#          '공유': 6,
#          '산': 22,
#          '준비': 18,
#          '콘트란쉐리': 1,
#          '루꼴': 8,
#          '하인': 1,
#          '갈릭': 1,
#          '마요네즈': 3,
#          '호울': 1,
#          '머스타드': 3,
#          '발사믹': 23,
#          '글': 4,
#          '레이즈': 2,
#          '전': 69,
#          '에어': 4,
#          '프라': 2,
#          '이기': 2,
#          '도': 83,
#          '분': 43,
#          '빠삭': 1,
#          '폭': 1,
#          '신한': 1,
#          '질감': 7,
#          '반': 18,
#          '한쪽': 5,
#          '홀': 3,
#          '개': 30,
#          '사이즈': 6,
#          '후': 21,
#          '듬뿍': 9,
#          '마지막': 8,
#          '조금': 85,
#          '단독': 16,
#          '촌': 137,
#          '안나': 55,
#          '레드와인': 16,
#          '궁합': 35,
#          '햄': 53,
#          '마냥': 2,
#          '한잔': 21,
#          '겨울': 1,
#          '밤': 6,
#          '이하': 2,
#          '요하': 3,
#          '몽리': 1,
#          '그': 33,
#          '짠맛': 40,
#          '곁': 12,
#          '요음': 21,
#          '음음': 1,
#          '새우': 1,
#          '빠에야': 6,
#          '마음': 80,
#          '듭니': 4,
#          '만족': 64,
#          '오늘': 19,
#          '과일': 60,
#          '성비': 41,
#          '가성': 101,
#          '샤퀴': 2,
#          '테리': 6,
#          '플래터': 12,
#          '대비': 85,
#          '템': 6,
#          '쪼롬': 6,
#          '즁': 2,
#          '맠': 1,
#          '대중': 18,
#          '햇': 13,
#          '상차림': 2,
#          '샤인': 7,
#          '머스켓': 3,
#          '조합': 49,
#          '젛네': 1,
#          '베이글': 18,
#          '여후': 1,
#          '기여': 1,
#          '감사': 28,
#          '요약': 4,
#          '매력': 9,
#          '사흘': 1,
#          '연달': 1,
#          '세': 5,
#          '가지': 15,
#          '야채': 12,
#          '역': 6,
#          '품질': 92,
#          '편이': 18,
#          '시간': 19,
#          '곧좀': 1,
#          '브리': 14,
#          '치증': 1,
#          '요양': 16,
#          '승부': 1,
#          '토스트': 23,
#          '회사': 1,
#          '언니': 2,
#          '찰떡': 32,
#          '기본': 12,
#          '제일': 39,
#          '품절': 23,
#          '다시': 52,
#          '왓': 3,
#          '아이': 36,
#          '단점': 4,
#          '감히': 1,
#          '쁘': 1,
#          '참깨스': 1,
#          '할인': 20,
#          '들러붙어서': 4,
#          '종이': 29,
#          '곳': 11,
#          '떡': 1,
#          '고기': 36,
#          '젤리': 1,
#          '여러가지': 9,
#          '벌써': 10,
#          '소가': 2,
#          '젤': 22,
#          '일반': 5,
#          '시중': 2,
#          '늘': 48,
#          '쟁여두': 10,
#          '일주일': 3,
#          '한번': 44,
#          '페스': 6,
#          '토': 8,
#          '복불복': 3,
#          '소금': 12,
#          '덩어리': 1,
#          '를': 4,
#          '파인애플': 8,
#          '홈파티': 29,
#          '꼬릿': 5,
#          '흠칫': 1,
#          '상관': 2,
#          '금액': 2,
#          '부위': 7,
#          '초보자': 11,
#          '손': 23,
#          '허브': 2,
#          '자극': 8,
#          '스파이': 4,
#          '시': 18,
#          '걱정': 25,
#          '프렌치': 3,
#          '토슷트': 1,
#          '소량': 6,
#          '덜': 46,
#          '비리': 27,
#          '흠': 12,
#          '고객': 282,
#          '입맛': 63,
#          '상품': 292,
#          '경험': 8,
#          '전달': 39,
#          '따름': 3,
#          '모든': 3,
#          '각': 5,
#          '카테고리': 2,
#          '별': 7,
#          '전문': 2,
#          '여가': 2,
#          '기준': 54,
#          '위원회': 2,
#          '통해': 42,
#          '심사': 2,
#          '대해': 38,
#          '유관': 30,
#          '부서': 41,
#          '선택': 8,
#          '과정': 5,
#          '관점': 2,
#          '상세': 5,
#          '도움': 18,
#          '드릴': 9,
#          '노력': 86,
#          '대한': 2,
#          '추가': 8,
#          '문의': 18,
#          '사항': 2,
#          '경우': 15,
#          '행복': 16,
#          '센터': 22,
#          '주시': 5,
#          '정성': 2,
#          '다해': 4,
#          '블루': 1,
#          '둘': 9,
#          '우선': 41,
#          '주신': 37,
#          '아쉬움': 23,
#          '이용': 67,
#          '부응': 25,
#          '저희': 46,
#          '지속': 79,
#          '관리': 44,
#          '자체': 47,
#          '판매': 56,
#          '수립': 41,
#          '먹거리': 41,
#          '일상': 22,
#          '더욱': 59,
#          '제공': 47,
#          '최선': 62,
#          '다': 41,
#          '또한': 28,
#          '채널': 35,
#          '목소리': 35,
#          '모니터링': 36,
#          '비롯': 34,
#          '서비스': 60,
#          '등': 51,
#          '개선': 40,
#          '의견': 30,
#          '불편': 60,
#          '점': 52,
#          '사과': 37,
#          '말씀': 107,
#          '및': 48,
#          '공급': 22,
#          '처': 24,
#          '추후': 33,
#          '약속': 23,
#          '귀': 42,
#          '나은': 44,
#          '쇼핑': 43,
#          '드림': 49,
#          '파스타': 44,
#          '트러플': 7,
#          '방금': 2,
#          '대도': 3,
#          '평소': 14,
#          '외국': 7,
#          '우리': 8,
#          '집': 57,
#          '가득': 1,
#          '기분': 17,
#          '오늘밤': 1,
#          '버터': 13,
#          '마늘': 6,
#          '훨': 3,
#          '괜': 12,
#          '쓰기': 10,
#          '굿이넹': 1,
#          '걸': 43,
#          '이번': 35,
#          '꽤': 25,
#          '제격': 17,
#          '후추': 19,
#          '리지': 4,
#          '널': 4,
#          '호불호': 15,
#          '듯굿': 1,
#          '일지': 3,
#          '도전': 24,
#          '향신료': 4,
#          '다만': 24,
#          '방식': 2,
#          '래서': 2,
#          '건': 23,
#          '알': 11,
#          '짐': 4,
#          '분위기': 19,
#          '예전': 14,
#          '호텔': 8,
#          '레스토랑': 6,
#          '루꼴라': 11,
#          '재현': 1,
#          '염도': 11,
#          '종종': 18,
#          '이': 61,
#          '건과류': 1,
#          '금상첨화': 5,
#          '매번': 22,
#          '인과': 4,
#          '마트': 18,
#          '엇': 6,
#          '기적': 4,
#          '골': 2,
#          '집앞': 1,
#          '편의점': 1,
#          '질': 14,
#          '기고': 4,
#          '뼈': 3,
#          '정착': 1,
#          '임': 5,
#          '첨': 5,
#          '토핑': 8,
#          '짱': 19,
#          '엇네': 3,
#          '유럽': 12,
#          '영빵': 1,
#          '발라': 10,
#          '구': 41,
#          '라면': 4,
#          '끼리': 6,
#          '나용': 9,
#          '순간': 3,
#          '아주': 80,
#          '항상': 53,
#          '코로나': 5,
#          '때문': 19,
#          '외식': 2,
#          '자제': 1,
#          '음식점': 3,
#          '아래': 3,
#          '상태': 20,
#          '워터': 10,
#          '아이스팩': 4,
#          '환경': 1,
#          '친': 1,
#          '팩': 10,
#          '사': 13,
#          '유통': 28,
#          '기한': 25,
#          '여기저기': 14,
#          '요가': 27,
#          '달달': 11,
#          '꿀': 19,
#          '분해': 3,
#          '간단': 6,
#          '크기': 13,
#          '오히려': 9,
#          '스탠다드': 1,
#          '질깃': 1,
#          '고무': 3,
#          '맘': 13,
#          '페어': 5,
#          '링': 7,
#          '매니아': 3,
#          '보기': 11,
#          '봄초': 1,
#          '말': 22,
#          '뭐': 23,
#          '카나페': 32,
#          '려고': 9,
#          '록': 1,
#          '계속': 45,
#          '뭔가': 8,
#          '맵': 8,
#          '절': 6,
#          '올리브': 38,
#          '스틱': 22,
#          '과자': 10,
#          '식전': 8,
#          '만해': 19,
#          '사람': 23,
#          '참고': 6,
#          '적지': 11,
#          '무조건': 6,
#          '선물': 16,
#          '크리스마스': 33,
#          '나름': 10,
#          '마나': 2,
#          '개인': 20,
#          '요기': 16,
#          '플랫': 1,
#          '브레드': 14,
#          '식사': 9,
#          '과': 12,
#          '오픈': 19,
#          '솔드아웃': 1,
#          '중이': 8,
#          '쵸리': 4,
#          '만': 14,
#          '샴페인': 4,
#          '거리': 5,
#          '사면': 10,
#          '나': 33,
#          '요추': 1,
#          '천해': 1,
#          '그대로': 15,
#          '파티': 36,
#          '모스': 2,
#          '카토': 2,
#          '이건': 43,
#          '미니': 3,
#          '막': 9,
#          '연말': 17,
#          '상하': 3,
#          '쾌쾌': 1,
#          '어찌': 1,
#          '처치': 3,
#          '곤란': 3,
#          '마': 2,
#          '닛': 1,
#          '멋': 1,
#          '크로와상': 7,
#          '굿굿구': 1,
#          '웃': 2,
#          '소스': 20,
#          '살걸': 3,
#          '후회': 7,
#          '질겨': 11,
#          '맛궁금': 1,
#          '피클': 3,
#          '별루': 3,
#          '제입': 6,
#          '엠': 1,
#          '별루에뇨': 1,
#          '문후': 1,
#          '새벽': 12,
#          '가입': 2,
#          '애용': 10,
#          '현지': 7,
#          '가족': 30,
#          '상온': 6,
#          '그동안': 4,
#          '프로슈토': 31,
#          '직접': 8,
#          '사실': 12,
#          '스타일': 7,
#          '강추활': 1,
#          '용도': 5,
#          '사진': 27,
#          '크레페': 2,
#          '살': 19,
#          '켯': 2,
#          '그때': 4,
#          '편차': 2,
#          '짤': 27,
#          '군데군데': 1,
#          '기네': 2,
#          '장마': 1,
#          '거의': 10,
#          '맛나여짭쪼름': 1,
#          '족': 3,
#          '짭쪼름': 18,
#          '개봉': 21,
#          '냠냠뇸뇸': 2,
#          '통째': 2,
#          '체리': 6,
#          '저번': 9,
#          '감칠맛': 28,
#          '독일': 1,
#          '교환학생': 1,
#          '괜츈': 4,
#          '방울토마토': 8,
#          '올리브오일': 15,
#          '대신': 10,
#          '방토': 1,
#          '거도': 3,
#          '핵노맛': 1,
#          '사지': 2,
#          '역대': 1,
#          '게': 23,
#          '쭉쭉': 4,
#          '접시': 4,
#          '완성': 9,
#          '자꾸': 11,
#          '유': 5,
#          '노굿': 1,
#          '간도': 13,
#          '짭조롬': 2,
#          '욤': 14,
#          '기름': 25,
#          '그거': 3,
#          '왜': 11,
#          '맛남': 8,
#          '이르케': 1,
#          '혼자': 6,
#          '완봉': 1,
#          '비스킷': 16,
#          '내심': 1,
#          '짜웠네': 1,
#          '단짝': 3,
#          '귯귯': 1,
#          '아아': 1,
#          '히히히': 2,
#          '요옹': 1,
#          '쫌': 4,
#          '신분': 5,
#          '이해': 2,
#          '머글': 1,
#          '금은': 1,
#          '예상': 8,
#          '가미': 5,
#          '페퍼로니': 5,
#          '런가': 12,
#          '욤굿': 2,
#          '아빠': 3,
#          '초이스': 2,
#          '굿베': 1,
#          '요타': 33,
#          '볶음밥': 5,
#          '마치': 1,
#          '베': 38,
#          '바람': 2,
#          '가장': 13,
#          '메뉴': 6,
#          '밖': 3,
#          '쫄깃': 15,
#          '한편': 3,
#          '기존': 5,
#          '번갈아': 1,
#          '밤새': 1,
#          '가능': 3,
#          '대서': 5,
#          '소주': 1,
#          '하니': 15,
#          '여행': 18,
#          '국내': 5,
#          '애': 16,
#          '발색제': 1,
#          '산도': 1,
#          '절제': 1,
#          '추억': 4,
#          '거만': 4,
#          '삿': 10,
#          '가끔': 26,
#          '요전': 6,
#          '루': 3,
#          '선': 8,
#          '농': 1,
#          '이름': 3,
#          '세일': 4,
#          '쪼름': 15,
#          '양상추': 5,
#          '당근': 3,
#          '드레싱': 4,
#          '대접': 2,
#          '레몬': 2,
#          '즙': 2,
#          '사용': 17,
#          '등분': 2,
#          '묘': 3,
#          '까르보나라': 2,
#          '포크': 11,
#          '베스트': 7,
#          '움': 5,
#          '괜춘': 2,
#          '생활': 1,
#          '관심': 1,
#          '이제야': 2,
#          '익일': 1,
#          '농도': 1,
#          '만족감': 1,
#          '쟁': 18,
#          '엉엉': 1,
#          '프랑스': 3,
#          '달라': 9,
#          '온건': 3,
#          '달': 4,
#          '핑거푸드': 11,
#          '건조': 8,
#          '육이': 2,
#          '둘째': 1,
#          '행주': 1,
#          '걸레': 1,
#          '훅': 1,
#          '짭쪼름해': 8,
#          '짭쪼롬하': 13,
#          '여': 13,
#          '가나': 3,
#          '아보': 2,
#          '신랑': 28,
#          '질리': 2,
#          '인도': 1,
#          '프로': 6,
#          '대박': 10,
#          '워낙': 19,
#          '무엇': 3,
#          '남': 2,
#          '앤': 2,
#          '계석': 1,
#          '구미': 1,
#          '예정': 31,
#          '중요시': 1,
#          '지지': 2,
#          '순삭': 13,
#          '지지도': 1,
#          '자도': 3,
#          '서여': 2,
#          '은근': 12,
#          '짱짱': 4,
#          '머스크': 1,
#          '히몽': 1,
#          '요건': 5,
#          '중화': 1,
#          '넉': 3,
#          '식': 20,
#          '적당': 13,
#          '옹': 5,
#          '얌': 1,
#          '쫀득': 8,
#          '살구': 2,
#          '잼': 10,
#          '식빵': 24,
#          '리조또': 3,
#          '해달': 1,
#          '몇번': 13,
#          '페퍼': 3,
#          '요안': 9,
#          '대치': 1,
#          '성공': 6,
#          '조식': 1,
#          '저녁': 11,
#          '건강': 3,
#          '첨가': 6,
#          '어간': 1,
#          '짭짜름해': 1,
#          '닥': 6,
#          '패킹': 1,
#          '맛음': 1,
#          '땐': 11,
#          '비릿': 8,
#          '건가': 2,
#          '숨': 1,
#          '괘': 1,
#          '버전': 1,
#          '너낌갠츈': 1,
#          '아보카도': 22,
#          '무화과': 19,
#          '시골': 2,
#          '노치': 1,
#          '쫄깃하': 3,
#          '호': 2,
#          '읍니': 3,
#          '회': 1,
#          '분량': 1,
#          '요조': 2,
#          '차려': 3,
#          '욥': 3,
#          '음식': 22,
#          '용이': 6,
#          '기': 8,
#          '친구': 25,
#          '자기': 5,
#          '장바구니': 2,
#          '인': 9,
#          '찌개': 1,
#          '등등': 3,
#          '갈릴': 2,
#          '에피타이저': 2,
#          '배달': 1,
#          '기사': 2,
#          '화이팅': 1,
#          '욬': 1,
#          '초리초': 12,
#          '길': 2,
#          '이제': 17,
#          '로만': 4,
#          '몽': 6,
#          '막걸리': 2,
#          '집들이': 10,
#          '기억': 7,
#          '물어': 1,
#          '의향': 9,
#          '딥': 2,
#          '거저': 2,
#          '못넉었디': 1,
#          '족발': 2,
#          '로': 13,
#          '위주': 3,
#          '꼰': 5,
#          '마컬': 2,
#          '쓱': 2,
#          '쫜득쫜': 1,
#          '득': 2,
#          '쫠깃쫠깃': 3,
#          '음가': 2,
#          '보관': 13,
#          '기간': 4,
#          '물건': 7,
#          '훌륭': 3,
#          '마시기': 3,
#          '홋': 1,
#          '일수': 2,
#          '보드': 5,
#          '매장': 1,
#          '가사': 1,
#          '눈': 3,
#          '중독': 14,
#          '엇어': 6,
#          '라클렛치즈': 1,
#          '쭌맛': 1,
#          '고': 4,
#          '까나페': 9,
#          '기념': 1,
#          '맛오': 1,
#          '핵맛': 2,
#          '잔': 5,
#          '슬라이드': 3,
#          '품': 5,
#          '최': 3,
#          '가요': 4,
#          '최근': 1,
#          '프렌치토스트': 9,
#          '플라스틱': 3,
#          '청포도': 6,
#          '토리': 1,
#          '장난': 2,
#          '테': 9,
#          '어디': 9,
#          '활용': 21,
#          '도도': 1,
#          '딱쫄깃쫄깃': 1,
#          '끝맛': 7,
#          '사기': 3,
#          '겹치기': 1,
#          '요물': 1,
#          '한국': 10,
#          '순': 2,
#          '사이사이': 18,
#          '비닐': 28,
#          '기도': 5,
#          '매각': 7,
#          '두툼': 1,
#          '타용': 1,
#          '맵진': 1,
#          '합리': 6,
#          '보지': 5,
#          '골드': 1,
#          '키위': 2,
#          '술술': 11,
#          '바질': 8,
#          '하루': 7,
#          '뒤': 7,
#          '라끌렛': 3,
#          '캠핑': 7,
#          '쫄깃쫄깃': 3,
#          '쫄깃해': 1,
#          '순식간': 3,
#          '본적': 2,
#          '취향': 17,
#          '딸': 10,
#          '맛난': 1,
#          '체다': 2,
#          '물기': 1,
#          '브루스': 1,
#          '게타': 1,
#          '식겁맛': 1,
#          '아이비': 8,
#          '마스': 4,
#          '카포네': 2,
#          '타잉': 1,
#          '바게트': 54,
#          '바케트': 2,
#          '부': 2,
#          '리타': 2,
#          '이예': 4,
#          '갑': 5,
#          '세상': 4,
#          '상': 7,
#          '남아': 4,
#          '안쥬': 1,
#          '장정': 2,
#          '안성': 1,
#          '마춤': 1,
#          '파뤼': 2,
#          '비주': 5,
#          '담당': 12,
#          '밋있': 1,
#          '네': 3,
#          '거기': 3,
#          '진심': 6,
#          '줜맛': 1,
#          '깡': 1,
#          '흡족': 1,
#          '김밥': 2,
#          '간': 9,
#          '내': 10,
#          '중간': 11,
#          '어': 5,
#          '두운': 3,
#          '색': 6,
#          '일단': 17,
#          '헤비': 2,
#          '나중': 11,
#          '려구': 1,
#          '거중': 2,
#          '싰는데': 1,
#          '요리': 17,
#          '재료': 20,
#          '매우': 11,
#          '트': 7,
#          '장미꽃': 1,
#          '모양': 5,
#          '색감': 1,
#          '귣': 1,
#          '꾸르맛살치촌': 1,
#          '노랑': 4,
#          '망고': 4,
#          '같이먹엇어': 1,
#          '남자친구': 4,
#          '눈물': 3,
#          '글썽': 1,
#          '짭쪼름쫄깃': 1,
#          ...})

# %%
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({'하몽': 1694, '와인': 1110, '안주': 925, '구매': 535, '치즈': 438, '메론': 401, '컬리': 393, '샌드위치': 353, '멜론': 320, '먹기': 297, '상품': 292, '고객': 282, '샐러드': 277, '리조': 248, '가격': 240, '주문': 229, '처음': 223, '냄새': 212, '라이스': 212, '그냥': 211, '생각': 201, '세라': 166, '마켓': 155, '최고': 154, '스페인': 131, '구입': 130, '베리': 128, '기대': 127, '맥주': 126, '후기': 125, '진짜': 123, '무난': 117, '정말': 107, '말씀': 107, '배송': 104, '술안주': 102, '가성': 101, '별로': 100, '제품': 99, '양도': 95, '다른': 93, '품질': 92, '자주': 91, '살짝': 87, '노력': 86, '보고': 85, '조금': 85, '대비': 85, '매콤': 
경우': 15, '호불호': 15, '그대로': 15, '올리브오일': 15, '쫄깃': 15, '하니': 15, '쪼름': 15, '엄마': 15, '일해': 15, '확인': 15, '지방': 15, '하몬': 15, '등급': 15, '이상': 14, '짭쪼름하': 14, '거부': 14, '브리': 14, '평소': 14, '예전': 14, '여기저기': 14, '브레드': 14, '중독': 14, '냉장고': 14, '육포': 14, '최애': 13, '강추': 13, '여러': 13, '조각': 13, '주말': 13, '버터': 13, '크기': 13, '간도': 13, '가장': 13, '짭쪼롬하': 13, '순삭': 13, '적당': 13, '몇번': 13, '보관': 13, '매일': 13, '시도': 13, '뚝딱': 13, '검수': 13, '언제': 13, '급사': 13, '양은': 13, '사랑': 13, '타파스': 12, '생햄': 12, '누락': 12, '짭쪼롬': 12, '아들': 12, '플래터': 12, '야채': 12, '기본': 12, '소금': 12, '유럽': 12, '새벽': 12, '사실': 12, '런가': 12, '은근': 12, '초리초': 12, '담당': 12, '위해': 12, '잘못': 12, '생으로': 12, '구비': 12, '참외': 12, '전혀': 11, '초보자': 11, '루꼴라': 11, '염도': 11, '달달': 11, '보기': 11, '적지': 11, '질겨': 11, '자꾸': 11, '포크': 11, '핑거푸드': 11, '저녁': 11, '술술': 11, '중간': 11, '나중': 11, '매우': 11, '수령': 11, '접수': 11, '벌써': 10, '쟁여두': 10, '쓰기': 10, '발라': 10, '워터': 10, '과자': 10, '나름': 10, '사면': 10, '애용': 10, '거의': 10, '대신': 10, '대박': 10, '집들이': 10, '한국': 10, '오븐': 10, '지난번': 10, '모짜렐라': 10, '양념': 10, '주로': 10, '레커': 9, '초리': 9, '채소': 9, '사이': 9, '듬뿍': 9, '매력': 9, '여러가지': 9, '드릴': 9, '나용': 9, '오히려': 9, '려고': 9, '식사': 9, '저번': 9, '완성': 9, '달라': 9, '요안': 9, '의향': 9, '까나페': 9, '프렌치토스트': 9, '어디': 9, '비교': 9, '소시지': 9, '다소': 9, '퀄리티': 9, '세번': 9, '저렴': 9, '자리': 8, '필름': 8, '필수': 8, '금방': 8, '루꼴': 8, '마지막': 8, '파인애플': 8, '자극': 8, ' ...

# %%
korean_stopwords_path = "korean_stopwords.txt"
with open(korean_stopwords_path, encoding='utf-8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
market_kurry_stopwords = ['하몽', '컬리', '고객', '마켓', '배송', '진짜', '주문' , '구매' , '보고', '자주', '말씀',
                          '상품', '후기' , '살짝']
for stopword in market_kurry_stopwords:
    stopwords.append(stopword)
    
remove_char_counter = Counter({x :remove_char_counter[x] for x in count if x not in stopwords})
print(remove_char_counter)
# Out:
